# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree

import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Dataset

# %%
dataset = pd.read_csv("Data/Satelite_dataset/sat_train.csv")

# %%
dataset
# Out:
#       Column1  Column2  Column3  Column4  Column5  Column6  Column7  Column8  \
# 0          92      115      120       94       84      102      106       79
# 1          84      102      106       79       84      102      102       83
# 2          84      102      102       83       80      102      102       79
# 3          80      102      102       79       84       94      102       79
# 4          84       94      102       79       80       94       98       76
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 4430       56       64      108       96       64       71      108       96
# 4431       64       71      108       96       68       75      108       96
# 4432       68       75      108       96       71       87      108       88
# 4433       71       87      108       88       71       91      100       81
# 4434       71       91      100       81       76       95      108       88
#
#       Column9  Column10  ...  Column28  Column29  Column30  Column31  \
# 0          84       102  ...       104        88       121       128
# 1          80       102  ...       100        84       107       113
# 2          84        94  ...        87        84        99       104
# 3          80        94  ...        79        84        99       104
# 4          80       102  ...        79        84       103       104
# ...       ...       ...  ...       ...       ...       ...       ...
# 4430       68        75  ...        92        66        83       108
# 4431       71        87  ...        96        66        87       104
# 4432       71        91  ...        89        63        87       104
# 4433       76        95  ...        89        70       100       104
# 4434       80        95  ...        85        70        91       104
#
#       Column32  Column33  Column34  Column35  Column36  Column37
# 0          100        84       107       113        87         3
# 1           87        84        99       104        79         3
# 2           79        84        99       104        79         3
# 3           79        84       103       104        79         3
# 4           79        79       107       109        87         3
# ...        ...       ...       ...       ...       ...       ...
# 4430        96        66        87       104        89         5
# 4431        89        63        87       104        89         5
# 4432        89        70       100       104        85         4
# 4433        85        70        91       104        85         4
# 4434        85        63        91       100        81         4
#
# [4435 rows x 37 columns]

# %%
x_train = dataset.iloc[:,:-1]
y_train = dataset.iloc[:, -1]

# %%
x_train
# Out:
#       Column1  Column2  Column3  Column4  Column5  Column6  Column7  Column8  \
# 0          92      115      120       94       84      102      106       79
# 1          84      102      106       79       84      102      102       83
# 2          84      102      102       83       80      102      102       79
# 3          80      102      102       79       84       94      102       79
# 4          84       94      102       79       80       94       98       76
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 4430       56       64      108       96       64       71      108       96
# 4431       64       71      108       96       68       75      108       96
# 4432       68       75      108       96       71       87      108       88
# 4433       71       87      108       88       71       91      100       81
# 4434       71       91      100       81       76       95      108       88
#
#       Column9  Column10  ...  Column27  Column28  Column29  Column30  \
# 0          84       102  ...       134       104        88       121
# 1          80       102  ...       128       100        84       107
# 2          84        94  ...       113        87        84        99
# 3          80        94  ...       104        79        84        99
# 4          80       102  ...       104        79        84       103
# ...       ...       ...  ...       ...       ...       ...       ...
# 4430       68        75  ...       108        92        66        83
# 4431       71        87  ...       108        96        66        87
# 4432       71        91  ...       104        89        63        87
# 4433       76        95  ...       104        89        70       100
# 4434       80        95  ...       104        85        70        91
#
#       Column31  Column32  Column33  Column34  Column35  Column36
# 0          128       100        84       107       113        87
# 1          113        87        84        99       104        79
# 2          104        79        84        99       104        79
# 3          104        79        84       103       104        79
# 4          104        79        79       107       109        87
# ...        ...       ...       ...       ...       ...       ...
# 4430       108        96        66        87       104        89
# 4431       104        89        63        87       104        89
# 4432       104        89        70       100       104        85
# 4433       104        85        70        91       104        85
# 4434       104        85        63        91       100        81
#
# [4435 rows x 36 columns]

# %%
y_train
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 4430    5
# 4431    5
# 4432    4
# 4433    4
# 4434    4
# Name: Column37, Length: 4435, dtype: int64

# %% [markdown]
# # Decision Tree

# %%
dtc = DecisionTreeClassifier(random_state=365, ccp_alpha=0.02)
# dtc02 = DecisionTreeClassifier(criterion="entropy")
# pruned_dtc01 = DecisionTreeClassifier(ccp_alpha=0.001)
# pruned_dtc02 = DecisionTreeClassifier(ccp_alpha=0.01)
# pruned_dtc03 = DecisionTreeClassifier(ccp_alpha=0.1)
# pruned_dtc04 = DecisionTreeClassifier(ccp_alpha=1)

# %%
model01 = dtc.fit(x_train, y_train)
# model02 = dtc02.fit(x,y)
# model03 = pruned_dtc01.fit(x, y)
# model04 = pruned_dtc02.fit(x, y)
# model05 = pruned_dtc03.fit(x, y)
# model06 = pruned_dtc04.fit(x, y)

# %% [markdown]
# # Plot

# %%
plot_tree(model01)
# Out:
# [Text(0.5, 0.9, 'x[16] <= 79.5\ngini = 0.808\nsamples = 4435\nvalue = [1072, 479, 961, 415, 470, 1038]'),
#  Text(0.4090909090909091, 0.7, 'x[19] <= 73.5\ngini = 0.764\nsamples = 3328\nvalue = [1052, 479, 61, 276, 469, 991]'),
#  Text(0.18181818181818182, 0.5, 'x[17] <= 61.5\ngini = 0.533\nsamples = 1404\nvalue = [48, 6, 6, 156, 288, 900]'),
#  Text(0.09090909090909091, 0.3, 'gini = 0.069\nsamples = 227\nvalue = [2, 1, 0, 0, 219, 5]'),
#  Text(0.2727272727272727, 0.3, 'gini = 0.399\nsamples = 1177\nvalue = [46, 5, 6, 156, 69, 895]'),
#  Text(0.6363636363636364, 0.5, 'x[17] <= 65.0\ngini = 0.651\nsamples = 1924\nvalue = [1004, 473, 55, 120, 181, 91]'),
#  Text(0.45454545454545453, 0.3, 'x[19] <= 90.5\ngini = 0.274\nsamples = 521\nvalue = [2, 436, 0, 0, 83, 0]'),
#  Text(0.36363636363636365, 0.1, 'gini = 0.32\nsamples = 93\nvalue = [2, 16, 0, 0, 75, 0]'),
#  Text(0.5454545454545454, 0.1, 'gini = 0.037\nsamples = 428\nvalue = [0, 420, 0, 0, 8, 0]'),
#  Text(0.8181818181818182, 0.3, 'x[20] <= 73.0\ngini = 0.471\nsamples = 1403\nvalue = [1002, 37, 55, 120, 98, 91]'),
#  Text(0.7272727272727273, 0.1, 'gini = 0.265\nsamples = 1123\nvalue = [958, 30, 9, 26, 82, 18]'),
#  Text(0.9090909090909091, 0.1, 'gini = 0.764\nsamples = 280\nvalue = [44, 7, 46, 94, 16, 73]'),
#  Text(0.5909090909090909, 0.7, 'gini = 0.321\nsamples = 1107\nvalue = [20, 0, 900, 139, 1, 47]')]

# %%
plt.figure(figsize=(15, 12))
plot_tree(model01, filled= True)
plt.show()

# %%
plt.figure(figsize=(15, 12))
plot_tree(model02, filled= True, class_names=label, feature_names=features)
plt.show()

# %%
plt.figure(figsize=(15, 12))
plot_tree(model03, filled= True, class_names=label, feature_names=features)
plt.show()

# %%
plt.figure(figsize=(15, 12))
plot_tree(model04, filled= True, class_names=label, feature_names=features)
plt.show()

# %%
plt.figure(figsize=(15, 12))
plot_tree(model05, filled= True, class_names=label, feature_names=features)
plt.show()

# %%
plt.figure(figsize=(15, 12))
plot_tree(model06, filled= True, class_names=label, feature_names=features)
plt.show()
